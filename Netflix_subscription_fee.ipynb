# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikandan-professional/Netflix-Subscriptions/blob/main/Netflix_subscription_fee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the Necessary Modules**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# #**Conversion of Dataframe**

# %%
a='https://raw.githubusercontent.com/Manikandan-professional/Netflix-Subscriptions/main/Netflix%20subscription%20fee%20Dec-2021.csv'
df=pd.DataFrame(pd.read_csv(a))
df.head()
# Out:
#   Country_code  ... Cost Per Month - Premium ($)
# 0           ar  ...                         9.26
# 1           au  ...                        16.39
# 2           at  ...                        20.32
# 3           be  ...                        20.32
# 4           bo  ...                        13.99
#
# [5 rows x 8 columns]

# %% [markdown]
# #**Top 10 Country wise Breakdown**

# %%
a1=df.sort_values(['Cost Per Month - Basic ($)'],ascending=False)
a1
# Out:
#    Country_code  ... Cost Per Month - Premium ($)
# 33           li  ...                        26.96
# 56           ch  ...                        26.96
# 13           dk  ...                        19.60
# 55           se  ...                        19.70
# 29           il  ...                        19.54
# ..          ...  ...                          ...
# 5            br  ...                         9.96
# 9            co  ...                         9.93
# 0            ar  ...                         9.26
# 26           in  ...                         8.60
# 59           tr  ...                         4.02
#
# [65 rows x 8 columns]

# %%
for i in range(0,10,1):
  print(a1.iloc[i:i+1,:4])
  print('*********************************************************************')
# Out:
#    Country_code        Country  Total Library Size  No. of TV Shows
# 33           li  Liechtenstein                3048             1712
# *********************************************************************
#    Country_code      Country  Total Library Size  No. of TV Shows
# 56           ch  Switzerland                5506             3654
# *********************************************************************
#    Country_code  Country  Total Library Size  No. of TV Shows
# 13           dk  Denmark                4558             2978
# *********************************************************************
#    Country_code Country  Total Library Size  No. of TV Shows
# 55           se  Sweden                4361             2973
# *********************************************************************
#    Country_code Country  Total Library Size  No. of TV Shows
# 29           il  Israel                5713             3650
# *********************************************************************
#   Country_code  Country  Total Library Size  No. of TV Shows
# 3           be  Belgium                4990             3374
# *********************************************************************
#    Country_code Country  Total Library Size  No. of TV Shows
# 17           fr  France                5445             3604
# *********************************************************************
#    Country_code Country  Total Library Size  No. of TV Shows
# 41           no  Norway                4528             2955
# *********************************************************************
#    Country_code Country  Total Library Size  No. of TV Shows
# 57           tw  Taiwan                5105             3134
# *********************************************************************
#    Country_code    Country  Total Library Size  No. of TV Shows
# 50           sg  Singapore                6303             4109
# *********************************************************************

# %% [markdown]
# #**Least 10 Country wise Breakdown**

# %%
a2=df.sort_values(['Cost Per Month - Basic ($)'],ascending=True)
a2
# Out:
#    Country_code  ... Cost Per Month - Premium ($)
# 59           tr  ...                         4.02
# 26           in  ...                         8.60
# 0            ar  ...                         9.26
# 9            co  ...                         9.93
# 5            br  ...                         9.96
# ..          ...  ...                          ...
# 29           il  ...                        19.54
# 55           se  ...                        19.70
# 13           dk  ...                        19.60
# 33           li  ...                        26.96
# 56           ch  ...                        26.96
#
# [65 rows x 8 columns]

# %%
a2=a2.reset_index()

# %%
country=[]
CPM_Basic=[]
CPM_Standard=[]
CPM_Premium=[]
for i in range(0,10,1):
  print(a2.iloc[i:i+1,:4])
  print('Cost Per Month in the Basic Rental in INR is: ',a2.iloc[i:i+1,6:7]['Cost Per Month - Basic ($)'][i]*72)
  CPM_Basic.append(a2.iloc[i:i+1,6:7]['Cost Per Month - Basic ($)'][i]*72)
  country.append(a2.iloc[i:i+1,2:3]['Country'][i])
  print('Cost Per Month in the Standard Rental in INR is: ',a2.iloc[i:i+1,7:8]['Cost Per Month - Standard ($)'][i]*72)
  CPM_Standard.append(a2.iloc[i:i+1,7:8]['Cost Per Month - Standard ($)'][i]*72)

  print('Cost Per Month in the Premium Rental in INR is: ',a2.iloc[i:i+1,8:9]['Cost Per Month - Premium ($)'][i]*72)
  CPM_Premium.append(a2.iloc[i:i+1,8:9]['Cost Per Month - Premium ($)'][i]*72)
  print('*********************************************************************')
# Out:
#    index Country_code Country  Total Library Size
# 0     59           tr  Turkey                4639
# Cost Per Month in the Basic Rental in INR is:  141.84
# Cost Per Month in the Standard Rental in INR is:  216.0
# Cost Per Month in the Premium Rental in INR is:  289.43999999999994
# *********************************************************************
#    index Country_code Country  Total Library Size
# 1     26           in   India                5843
# Cost Per Month in the Basic Rental in INR is:  190.08
# Cost Per Month in the Standard Rental in INR is:  475.92
# Cost Per Month in the Premium Rental in INR is:  619.1999999999999
# *********************************************************************
#    index Country_code    Country  Total Library Size
# 2      0           ar  Argentina                4760
# Cost Per Month in the Basic Rental in INR is:  269.28000000000003
# Cost Per Month in the Standard Rental in INR is:  453.59999999999997
# Cost Per Month in the Premium Rental in INR is:  666.72
# *********************************************************************
#    index Country_code   Country  Total Library Size
# 3      9           co  Colombia                4991
# Cost Per Month in the Basic Rental in INR is:  310.32
# Cost Per Month in the Standard Rental in INR is:  493.92
# Cost Per Month in the Premium Rental in INR is:  714.96
# *********************************************************************
#    index Country_code Country  Total Library Size
# 4      5           br  Brazil                4972
# Cost Per Month in the Basic Rental in INR is:  331.92
# Cost Per Month in the Standard Rental in INR is:  511.92
# Cost Per Month in the Premium Rental in INR is:  717.1200000000001
# *********************************************************************
#    index Country_code  Country  Total Library Size
# 5     60           ua  Ukraine                5336
# Cost Per Month in the Basic Rental in INR is:  406.08
# Cost Per Month in the Standard Rental in INR is:  609.1200000000001
# Cost Per Month in the Premium Rental in INR is:  812.8799999999999
# *********************************************************************
#    index Country_code Country  Total Library Size
# 6     43           pe    Peru                4986
# Cost Per Month in the Basic Rental in INR is:  439.92
# Cost Per Month in the Standard Rental in INR is:  616.32
# Cost Per Month in the Premium Rental in INR is:  792.72
# *********************************************************************
#    index Country_code       Country  Total Library Size
# 7     52           za  South Africa                5736
# Cost Per Month in the Basic Rental in INR is:  450.71999999999997
# Cost Per Month in the Standard Rental in INR is:  723.6
# Cost Per Month in the Premium Rental in INR is:  905.76
# *********************************************************************
#    index Country_code Country  Total Library Size
# 8     36           mx  Mexico                4993
# Cost Per Month in the Basic Rental in INR is:  476.64
# Cost Per Month in the Standard Rental in INR is:  750.96
# Cost Per Month in the Premium Rental in INR is:  1025.28
# *********************************************************************
#    index Country_code Country  Total Library Size
# 9      8           cl   Chile                4994
# Cost Per Month in the Basic Rental in INR is:  509.04
# Cost Per Month in the Standard Rental in INR is:  713.52
# Cost Per Month in the Premium Rental in INR is:  917.28
# *********************************************************************

# %%
country
# Out:
# ['Turkey',
#  'India',
#  'Argentina',
#  'Colombia',
#  'Brazil',
#  'Ukraine',
#  'Peru',
#  'South Africa',
#  'Mexico',
#  'Chile']

# %%
plt.figure(figsize=(16,8),dpi=80)
ax=plt.axes()
ax.set_facecolor('black')

plt.bar(country,CPM_Basic,color='white')
plt.title('Country Name vs Basic Plan Rates with Bar Graph',color='blue',fontsize=25)
plt.xlabel('Country Name',color='blue',fontsize=20)
plt.ylabel('Rates for Basic Plan',color='blue',fontsize=20)
plt.xticks(rotation=50,color='blue',fontsize=20)
plt.yticks(color='blue',fontsize=20)

plt.show()

# %%
a2=df.sort_values(['Cost Per Month - Standard ($)'],ascending=True)
a2
# Out:
#    Country_code  ... Cost Per Month - Premium ($)
# 59           tr  ...                         4.02
# 0            ar  ...                         9.26
# 26           in  ...                         8.60
# 9            co  ...                         9.93
# 5            br  ...                         9.96
# ..          ...  ...                          ...
# 29           il  ...                        19.54
# 17           fr  ...                        20.32
# 3            be  ...                        20.32
# 33           li  ...                        26.96
# 56           ch  ...                        26.96
#
# [65 rows x 8 columns]

# %%
a2=a2.reset_index()

# %%
country=[]
CPM_Basic=[]
CPM_Standard=[]
CPM_Premium=[]
for i in range(0,10,1):
  print(a2.iloc[i:i+1,:4])
  print('Cost Per Month in the Basic Rental in INR is: ',a2.iloc[i:i+1,6:7]['Cost Per Month - Basic ($)'][i]*72)
  CPM_Basic.append(a2.iloc[i:i+1,6:7]['Cost Per Month - Basic ($)'][i]*72)
  country.append(a2.iloc[i:i+1,2:3]['Country'][i])
  print('Cost Per Month in the Standard Rental in INR is: ',a2.iloc[i:i+1,7:8]['Cost Per Month - Standard ($)'][i]*72)
  CPM_Standard.append(a2.iloc[i:i+1,7:8]['Cost Per Month - Standard ($)'][i]*72)

  print('Cost Per Month in the Premium Rental in INR is: ',a2.iloc[i:i+1,8:9]['Cost Per Month - Premium ($)'][i]*72)
  CPM_Premium.append(a2.iloc[i:i+1,8:9]['Cost Per Month - Premium ($)'][i]*72)
  print('*********************************************************************')
# Out:
#    index Country_code Country  Total Library Size
# 0     59           tr  Turkey                4639
# Cost Per Month in the Basic Rental in INR is:  141.84
# Cost Per Month in the Standard Rental in INR is:  216.0
# Cost Per Month in the Premium Rental in INR is:  289.43999999999994
# *********************************************************************
#    index Country_code    Country  Total Library Size
# 1      0           ar  Argentina                4760
# Cost Per Month in the Basic Rental in INR is:  269.28000000000003
# Cost Per Month in the Standard Rental in INR is:  453.59999999999997
# Cost Per Month in the Premium Rental in INR is:  666.72
# *********************************************************************
#    index Country_code Country  Total Library Size
# 2     26           in   India                5843
# Cost Per Month in the Basic Rental in INR is:  190.08
# Cost Per Month in the Standard Rental in INR is:  475.92
# Cost Per Month in the Premium Rental in INR is:  619.1999999999999
# *********************************************************************
#    index Country_code   Country  Total Library Size
# 3      9           co  Colombia                4991
# Cost Per Month in the Basic Rental in INR is:  310.32
# Cost Per Month in the Standard Rental in INR is:  493.92
# Cost Per Month in the Premium Rental in INR is:  714.96
# *********************************************************************
#    index Country_code Country  Total Library Size
# 4      5           br  Brazil                4972
# Cost Per Month in the Basic Rental in INR is:  331.92
# Cost Per Month in the Standard Rental in INR is:  511.92
# Cost Per Month in the Premium Rental in INR is:  717.1200000000001
# *********************************************************************
#    index Country_code  Country  Total Library Size
# 5     60           ua  Ukraine                5336
# Cost Per Month in the Basic Rental in INR is:  406.08
# Cost Per Month in the Standard Rental in INR is:  609.1200000000001
# Cost Per Month in the Premium Rental in INR is:  812.8799999999999
# *********************************************************************
#    index Country_code Country  Total Library Size
# 6     43           pe    Peru                4986
# Cost Per Month in the Basic Rental in INR is:  439.92
# Cost Per Month in the Standard Rental in INR is:  616.32
# Cost Per Month in the Premium Rental in INR is:  792.72
# *********************************************************************
#    index Country_code      Country  Total Library Size
# 7     44           ph  Philippines                6362
# Cost Per Month in the Basic Rental in INR is:  529.1999999999999
# Cost Per Month in the Standard Rental in INR is:  658.08
# Cost Per Month in the Premium Rental in INR is:  786.96
# *********************************************************************
#    index Country_code Country  Total Library Size
# 8      8           cl   Chile                4994
# Cost Per Month in the Basic Rental in INR is:  509.04
# Cost Per Month in the Standard Rental in INR is:  713.52
# Cost Per Month in the Premium Rental in INR is:  917.28
# *********************************************************************
#    index Country_code    Country  Total Library Size
# 9     23           hk  Hong Kong                4746
# Cost Per Month in the Basic Rental in INR is:  581.76
# Cost Per Month in the Standard Rental in INR is:  720.0
# Cost Per Month in the Premium Rental in INR is:  858.96
# *********************************************************************

# %%
plt.figure(figsize=(16,8),dpi=80)
ax=plt.axes()
ax.set_facecolor('black')

plt.bar(country,CPM_Standard,color='white')
plt.title('Country Name vs Standard Plan Rates with Bar Graph',color='blue',fontsize=25)
plt.xlabel('Country Name',color='blue',fontsize=20)
plt.ylabel('Rates for Standard Plan',color='blue',fontsize=20)
plt.xticks(rotation=50,color='blue',fontsize=20)
plt.yticks(color='blue',fontsize=20)

plt.show()

# %%
a2=df.sort_values(['Cost Per Month - Premium ($)'],ascending=True)
a2
# Out:
#    Country_code  ... Cost Per Month - Premium ($)
# 59           tr  ...                         4.02
# 26           in  ...                         8.60
# 0            ar  ...                         9.26
# 9            co  ...                         9.93
# 5            br  ...                         9.96
# ..          ...  ...                          ...
# 30           it  ...                        20.32
# 49           sm  ...                        20.32
# 19           gi  ...                        20.32
# 33           li  ...                        26.96
# 56           ch  ...                        26.96
#
# [65 rows x 8 columns]

# %%
a2=a2.reset_index()

# %%
country=[]
CPM_Basic=[]
CPM_Standard=[]
CPM_Premium=[]
for i in range(0,10,1):
  print(a2.iloc[i:i+1,:4])
  print('Cost Per Month in the Basic Rental in INR is: ',a2.iloc[i:i+1,6:7]['Cost Per Month - Basic ($)'][i]*72)
  CPM_Basic.append(a2.iloc[i:i+1,6:7]['Cost Per Month - Basic ($)'][i]*72)
  country.append(a2.iloc[i:i+1,2:3]['Country'][i])
  print('Cost Per Month in the Standard Rental in INR is: ',a2.iloc[i:i+1,7:8]['Cost Per Month - Standard ($)'][i]*72)
  CPM_Standard.append(a2.iloc[i:i+1,7:8]['Cost Per Month - Standard ($)'][i]*72)

  print('Cost Per Month in the Premium Rental in INR is: ',a2.iloc[i:i+1,8:9]['Cost Per Month - Premium ($)'][i]*72)
  CPM_Premium.append(a2.iloc[i:i+1,8:9]['Cost Per Month - Premium ($)'][i]*72)
  print('*********************************************************************')
# Out:
#    index Country_code Country  Total Library Size
# 0     59           tr  Turkey                4639
# Cost Per Month in the Basic Rental in INR is:  141.84
# Cost Per Month in the Standard Rental in INR is:  216.0
# Cost Per Month in the Premium Rental in INR is:  289.43999999999994
# *********************************************************************
#    index Country_code Country  Total Library Size
# 1     26           in   India                5843
# Cost Per Month in the Basic Rental in INR is:  190.08
# Cost Per Month in the Standard Rental in INR is:  475.92
# Cost Per Month in the Premium Rental in INR is:  619.1999999999999
# *********************************************************************
#    index Country_code    Country  Total Library Size
# 2      0           ar  Argentina                4760
# Cost Per Month in the Basic Rental in INR is:  269.28000000000003
# Cost Per Month in the Standard Rental in INR is:  453.59999999999997
# Cost Per Month in the Premium Rental in INR is:  666.72
# *********************************************************************
#    index Country_code   Country  Total Library Size
# 3      9           co  Colombia                4991
# Cost Per Month in the Basic Rental in INR is:  310.32
# Cost Per Month in the Standard Rental in INR is:  493.92
# Cost Per Month in the Premium Rental in INR is:  714.96
# *********************************************************************
#    index Country_code Country  Total Library Size
# 4      5           br  Brazil                4972
# Cost Per Month in the Basic Rental in INR is:  331.92
# Cost Per Month in the Standard Rental in INR is:  511.92
# Cost Per Month in the Premium Rental in INR is:  717.1200000000001
# *********************************************************************
#    index Country_code      Country  Total Library Size
# 5     44           ph  Philippines                6362
# Cost Per Month in the Basic Rental in INR is:  529.1999999999999
# Cost Per Month in the Standard Rental in INR is:  658.08
# Cost Per Month in the Premium Rental in INR is:  786.96
# *********************************************************************
#    index Country_code Country  Total Library Size
# 6     43           pe    Peru                4986
# Cost Per Month in the Basic Rental in INR is:  439.92
# Cost Per Month in the Standard Rental in INR is:  616.32
# Cost Per Month in the Premium Rental in INR is:  792.72
# *********************************************************************
#    index Country_code  Country  Total Library Size
# 7     60           ua  Ukraine                5336
# Cost Per Month in the Basic Rental in INR is:  406.08
# Cost Per Month in the Standard Rental in INR is:  609.1200000000001
# Cost Per Month in the Premium Rental in INR is:  812.8799999999999
# *********************************************************************
#    index Country_code    Country  Total Library Size
# 8     23           hk  Hong Kong                4746
# Cost Per Month in the Basic Rental in INR is:  581.76
# Cost Per Month in the Standard Rental in INR is:  720.0
# Cost Per Month in the Premium Rental in INR is:  858.96
# *********************************************************************
#    index Country_code   Country  Total Library Size
# 9     58           th  Thailand                4948
# Cost Per Month in the Basic Rental in INR is:  600.48
# Cost Per Month in the Standard Rental in INR is:  750.96
# Cost Per Month in the Premium Rental in INR is:  901.4399999999999
# *********************************************************************

# %%
plt.figure(figsize=(16,8),dpi=80)
ax=plt.axes()
ax.set_facecolor('black')

plt.bar(country,CPM_Premium,color='white')
plt.title('Country Name vs Premium Plan Rates with Bar Graph',color='blue',fontsize=25)
plt.xlabel('Country Name',color='blue',fontsize=20)
plt.ylabel('Rates for Premium Plan',color='blue',fontsize=20)
plt.xticks(rotation=50,color='blue',fontsize=20)
plt.yticks(color='blue',fontsize=20)

plt.show()

# %% [markdown]
# # **Calculation on Average Price of the Subscription Plans**

# %%
df['Average Plan']=(df['Cost Per Month - Basic ($)']+df['Cost Per Month - Premium ($)']+df['Cost Per Month - Standard ($)'])/3

# %% [markdown]
# # **Top 10 Countries of Netflix Subscription plan from low to high**

# %%
a3=df.sort_values(['Average Plan'])
a3.head(10)
# Out:
#    Country_code       Country  ...  Cost Per Month - Premium ($)  Average Plan
# 59           tr        Turkey  ...                          4.02      2.996667
# 26           in         India  ...                          8.60      5.950000
# 0            ar     Argentina  ...                          9.26      6.433333
# 9            co      Colombia  ...                          9.93      7.033333
# 5            br        Brazil  ...                          9.96      7.226667
# 60           ua       Ukraine  ...                         11.29      8.463333
# 43           pe          Peru  ...                         11.01      8.560000
# 44           ph   Philippines  ...                         10.93      9.140000
# 52           za  South Africa  ...                         12.58      9.630000
# 8            cl         Chile  ...                         12.74      9.906667
#
# [10 rows x 9 columns]

# %% [markdown]
# # **Pictorial Representation on top 10 Averaged Price from low to high**

# %%
a3=a3.reset_index()

# %%
countrys=[]
INR=[]
for i in range(0,10,1):
  countrys.append(a3.iloc[i:i+1,2:3]['Country'][i])
  INR.append(a3.iloc[i:i+1,9:10]['Average Plan'][i])

# %%
plt.figure(figsize=(16,8),dpi=80)
ax=plt.axes()
ax.set_facecolor('black')

plt.bar(countrys,INR,color='white',width=0.5)
plt.title('Country Name vs Average Plan Rates with Bar Graph',color='blue',fontsize=25)
plt.xlabel('Country Name',color='blue',fontsize=20)
plt.ylabel('Rates for Average Plan',color='blue',fontsize=20)
plt.xticks(rotation=50,color='blue',fontsize=20)
plt.yticks(color='blue',fontsize=20)

plt.show()
